# %%
import pandas as pd

# %%
df = pd.read_csv('extracted_dataset/images_info.csv')
df.index = df['body_region']+'/'+df['patient_id']+'.'+df['content_type']
df = df.drop(columns=['content_type','image_urls'])
df.to_csv('extracted_dataset/metainfo.csv')
df
# Out:
#                            patient_id  age_month  is_male body_region
# thumb/3M Thumb_0.jpg       3M Thumb_0         36     True       thumb
# thumb/3M Thumb_1.jpg       3M Thumb_1         36     True       thumb
# thumb/3M Thumb_2.jpg       3M Thumb_2         36     True       thumb
# finger/13M Finger_0.jpg  13M Finger_0        156     True      finger
# finger/13M Finger_1.jpg  13M Finger_1        156     True      finger
# ...                               ...        ...      ...         ...
# hand/20M Hand_1.jpg        20M Hand_1        240     True        hand
# hand/20M Hand_1.jpg        20M Hand_1        240     True        hand
# hand/20M Hand_2.jpg        20M Hand_2        240     True        hand
# hand/20M Hand_2.jpg        20M Hand_2        240     True        hand
# hand/20M Hand_2.jpg        20M Hand_2        240     True        hand
#
# [1975 rows x 4 columns]
